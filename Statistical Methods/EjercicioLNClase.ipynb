# %%
head(cars)
str(cars)
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4
# 4 7     22
# 5 8     16
# 6 9     10
# 'data.frame':	50 obs. of  2 variables:
#  $ speed: num  4 4 7 7 8 9 10 10 10 11 ...
#  $ dist : num  2 10 4 22 16 10 18 26 34 17 ...

# %%
cov(speed, dist)
# Out:
# [1] 109.9469

# %%
cov(speed, 2*dist)
# Out:
# [1] 219.8939

# %%
cor(speed, dist)
# Out:
# [1] 0.8068949

# %%
set.seed(20)
a <- rnorm(50)
ejemplo_perfecto <- data.frame(speed = cars$speed, var = cars$speed + a)

# %%
plot(ejemplo_perfecto$speed, ejemplo_perfecto$var)
# Out:
# plot without title

# %%
regresion_coches <- lm(dist ~ speed, data = cars)

summary(regresion_coches)
# Out:
# Call:
# lm(formula = dist ~ speed, data = cars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -29.069  -9.525  -2.272   9.215  43.201
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -17.5791     6.7584  -2.601   0.0123 *
# speed         3.9324     0.4155   9.464 1.49e-12 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 15.38 on 48 degrees of freedom
# Multiple R-squared:  0.6511,	Adjusted R-squared:  0.6438
# F-statistic: 89.57 on 1 and 48 DF,  p-value: 1.49e-12

# %%
hist(regresion_coches$residual)
# Out:
# Plot with title "Histogram of regresion_coches$residual"

# %%
shapiro.test(regresion_coches$residual)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  regresion_coches$residual
# W = 0.94509, p-value = 0.02152

# %%
plot(regresion_coches)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
